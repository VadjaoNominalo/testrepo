# %% [markdown]
# <h1>Мой ноутбук Jupyter в IBM Watson Studio</h1>

# %% [markdown]
# <b>VADIM FILONOV</b>
# Data Scientist

# %% [markdown]
# <i>I like this profession!</i>

# %% [markdown]
# <h3>This code prints "Hello world"</h3>

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# <ul><li>Hi</li></ul><ol><li>Hi</li></ol><s>Hi</s>
